# %%
# !pip install groq
# Out:
# Collecting groq
#   Downloading groq-1.0.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from groq) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from groq) (2.12.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /usr/local/lib/python3.12/dist-packages (from groq) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->groq) (3.11)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->groq) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq) (0.4.2)
# Downloading groq-1.0.0-py3-none-any.whl (138 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.3/138.3 kB 10.7 MB/s eta 0:00:00
# Installing collected packages: groq
# Successfully installed groq-1.0.0

# %%
from groq import Groq
import os
from google.colab import userdata
client = Groq(api_key=userdata.get("GROQ_API_KEY"))
response = client.chat.completions.create(
model="llama-3.3-70b-versatile",
messages=[{"role": "user", "content": "Explain AI in simple terms"}]
)
print(response.choices[0].message.content)
# Out:
# I'll break down AI in simple terms.
#
# **What is AI?**
# AI stands for Artificial Intelligence. It's like a computer program that can think and learn like a human being. It's designed to perform tasks that normally require human intelligence, such as:
#
# * Problem-solving
# * Learning from experience
# * Recognizing patterns
# * Understanding language
# * Making decisions
#
# **How does AI work?**
# Imagine you're teaching a child to recognize cats and dogs. You show them many pictures of cats and dogs, and they start to learn the differences. AI works in a similar way:
#
# 1. **Training**: AI is shown a huge amount of data (like pictures, text, or sounds).
# 2. **Learning**: The AI program analyzes the data and finds patterns.
# 3. **Improving**: The AI uses what it's learned to make predictions or decisions.
#
# **Types of AI:**
#
# 1. **Narrow AI**: Designed to perform a specific task, like recognizing faces or playing chess.
# 2. **General AI**: Aims to be as smart as a human being, able to learn and apply knowledge across many areas.
# 3. **Super AI**: Even more advanced than General AI, with capabilities beyond human intelligence.
#
# **Examples of AI in everyday life:**
#
# 1. Virtual assistants like Siri, Alexa, or Google Assistant
# 2. Image recognition in Facebook or Google Photos
# 3. Self-driving cars
# 4. Personalized product recommendations on online shopping platforms
# 5. Chatbots that help with customer support
#
# **In summary**, AI is a computer program that can think, learn, and perform tasks like a human being. It's trained on data, learns from experience, and can make decisions or predictions. AI is already present in many aspects of our lives, and it's becoming increasingly important in various industries.

# %%
from groq import Groq
client = Groq(api_key=userdata.get("GROQ_API_KEY"))
conversation = []
print("Chatbot started. Type 'exit' to quit.")
while True:
  user_input = input("You: ")
  if user_input.lower() == "exit":
    print("Goodbye my friend!")
    break
  conversation.append({"role": "user", "content": user_input})
  response = client.chat.completions.create(
  model="llama-3.3-70b-versatile",
  messages=conversation
  )
  reply = response.choices[0].message.content
  conversation.append({"role": "assistant", "content": reply})
  print("Bot:", reply)
# Out:
# Chatbot started. Type 'exit' to quit.
# You: exit
# Goodbye my friend!
